# %% [markdown]
# # 프로젝트 : 얼굴을 인식하여 캐릭터 씌우기
#
# ## Face Detection vs Face Recognition
#
# Face Detection : 영상 속에서 사람의 얼굴을 찾는 것.
# Face Recognition : 영상 속의 얼굴이 어떤 사람인지 알아맞추는 것.
#
# mediapipe 라이브러리를 활용.

# %%
import cv2
import mediapipe as mp

# 얼굴을 찾고, 찾은 얼굴에 표시를 해주기 위한 변수 정의
mp_face_detection = mp.solutions.face_detection # 얼굴 검출을 위한 face_detection 모듈을 사용
mp_drawing = mp.solutions.drawing_utils # 얼굴의 특징을 그리기 위한 drawing_utils 모듈을 사용


# 동영상 파일 열기
cap = cv2.VideoCapture('face.mp4')

with mp_face_detection.FaceDetection(  # with문 : with루프 끝나면 close()할 필요 없이 자동으로 닫힌다.
    model_selection=0, min_detection_confidence=0.7) as face_detection:
    # model selection : 공식 문서에 따르면 모델 0은 근거리 얼굴에 적합하고, 1은 5미터 정도에 적합하다.
    # min_detection_confidence : 얼굴 인식을 위한 쓰레쉬홀드. 신뢰도.
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("no frame.")
            break

        # To improve performance, optionally mark the image as not writeable to
        # pass by reference.
        image.flags.writeable = False
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        results = face_detection.process(image)

        # Draw the face detection annotations on the image.
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        if results.detections:
            for detection in results.detections:
                mp_drawing.draw_detection(image, detection) # detection에는 신뢰도, location_data 등이 들어가 있다.
                                                            # 내부에 6 부분의 특징(눈, 코, 입 중심, 귀) 정보.
                
                keypoints = detection.location_data.relative_keypoints 
                right_eye = keypoints[0] # keypoints의 첫 번째 요소는 오른쪽 눈의 좌표이다. 딕셔너리 {x : ~, y : ~}으로 구성.
                left_eye = keypoints[1] # keypoints의 두 번째 요소는 왼쪽 눈의 좌표이다.
                
                # 눈 좌표를 영상에 맞게 조절.
                h, w, _ = image.shape # 이미지로부터 height, width, 크기 정보를 가져온다.
                right_eye = (int(right_eye.x * width ), int(right_eye.y * height))
                left_eye = (int(left_eye.x * width ), int(right_eye.y * height))
                
        # Flip the image horizontally for a selfie-view display.
        cv2.imshow('MediaPipe Face Detection', cv2.resize(image, None, fx = 0.5, fy = 0.5))
        if cv2.waitKey(1) == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# label_id: 0
# score: 0.972063422203064
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34010049700737
#     ymin: 0.27738773822784424
#     width: 0.16470429301261902
#     height: 0.2928076982498169
#   }
#   relative_keypoints {
#     x: 0.39748260378837585
#     y: 0.3514038920402527
#   }
#   relative_keypoints {
#     x: 0.472693532705307
#     y: 0.3491246700286865
#   }
#   relative_keypoints {
#     x: 0.4475392699241638
#     y: 0.41251301765441895
#   }
#   relative_keypoints {
#     x: 0.4445818364620209
#     y: 0.4767593741416931
#   }
#   relative_keypoints {
#     x: 0.3378288745880127
#     y: 0.39561253786087036
#   }
#   relative_keypoints {
#     x: 0.49736836552619934
#     y: 0.38518768548965454
#   }
# }
#
# label_id: 0
# score: 0.9679462313652039
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.33311721682548523
#     ymin: 0.2777583599090576
#     width: 0.16289886832237244
#     height: 0.2895984649658203
#   }
#   relative_keypoints {
#     x: 0.39025190472602844
#     y: 0.34613025188446045
#   }
#   relative_keypoints {
#     x: 0.4635593593120575
#     y: 0.3408070206642151
#   }
#   relative_keypoints {
#     x: 0.4400666356086731
#     y: 0.39819639921188354
#   }
#   relative_keypoints {
#     x: 0.43705520033836365
#     y: 0.46664613485336304
#   }
#   relative_keypoints {
#     x: 0.33068424463272095
#     y: 0.4004088044166565
#   }
#   relative_keypoints {
#     x: 0.48784804344177246
#     y: 0.3846399784088135
#   }
# }
#
# label_id: 0
# score: 0.9694578051567078
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3212532103061676
#     ymin: 0.2832770347595215
#     width: 0.17025944590568542
#     height: 0.30268406867980957
#   }
#   relative_keypoints {
#     x: 0.38045239448547363
#     y: 0.35678762197494507
#   }
#   relative_keypoints {
#     x: 0.45588070154190063
#     y: 0.3593894839286804
#   }
#   relative_keypoints {
#     x: 0.4281751215457916
#     y: 0.4218774437904358
#   }
#   relative_keypoints {
#     x: 0.4240167737007141
#     y: 0.487396776676178
#   }
#   relative_keypoints {
#     x: 0.3226909041404724
#     y: 0.3943735957145691
#   }
#   relative_keypoints {
#     x: 0.48408418893814087
#     y: 0.39295703172683716
#   }
# }
#
# label_id: 0
# score: 0.9699758291244507
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.30295276641845703
#     ymin: 0.27950626611709595
#     width: 0.17640388011932373
#     height: 0.3136065602302551
#   }
#   relative_keypoints {
#     x: 0.3722819983959198
#     y: 0.3617262840270996
#   }
#   relative_keypoints {
#     x: 0.444297730922699
#     y: 0.3671398162841797
#   }
#   relative_keypoints {
#     x: 0.42163801193237305
#     y: 0.43771374225616455
#   }
#   relative_keypoints {
#     x: 0.4156920313835144
#     y: 0.5011518001556396
#   }
#   relative_keypoints {
#     x: 0.30874255299568176
#     y: 0.38763540983200073
#   }
#   relative_keypoints {
#     x: 0.4657917320728302
#     y: 0.3904038667678833
#   }
# }
#
# label_id: 0
# score: 0.9637212157249451
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.29659610986709595
#     ymin: 0.2785447835922241
#     width: 0.17934933304786682
#     height: 0.3188443183898926
#   }
#   relative_keypoints {
#     x: 0.36583229899406433
#     y: 0.36422187089920044
#   }
#   relative_keypoints {
#     x: 0.4393121302127838
#     y: 0.3659306764602661
#   }
#   relative_keypoints {
#     x: 0.41555580496788025
#     y: 0.4391636848449707
#   }
#   relative_keypoints {
#     x: 0.4101562798023224
#     y: 0.5033782124519348
#   }
#   relative_keypoints {
#     x: 0.3013315498828888
#     y: 0.39167696237564087
#   }
#   relative_keypoints {
#     x: 0.4624367356300354
#     y: 0.38936638832092285
#   }
# }
#
# label_id: 0
# score: 0.9585813879966736
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.287386953830719
#     ymin: 0.2801735997200012
#     width: 0.17403125762939453
#     height: 0.30938953161239624
#   }
#   relative_keypoints {
#     x: 0.3593442440032959
#     y: 0.36061155796051025
#   }
#   relative_keypoints {
#     x: 0.43022745847702026
#     y: 0.3639378547668457
#   }
#   relative_keypoints {
#     x: 0.4104216992855072
#     y: 0.4318382740020752
#   }
#   relative_keypoints {
#     x: 0.40388137102127075
#     y: 0.4952801465988159
#   }
#   relative_keypoints {
#     x: 0.2914546728134155
#     y: 0.3924104571342468
#   }
#   relative_keypoints {
#     x: 0.44701072573661804
#     y: 0.39236462116241455
#   }
# }
#
# label_id: 0
# score: 0.9659571051597595
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2872592508792877
#     ymin: 0.2813956141471863
#     width: 0.16742727160453796
#     height: 0.29764896631240845
#   }
#   relative_keypoints {
#     x: 0.3540729582309723
#     y: 0.3548375964164734
#   }
#   relative_keypoints {
#     x: 0.4271748960018158
#     y: 0.3575289845466614
#   }
#   relative_keypoints {
#     x: 0.40702366828918457
#     y: 0.4173966646194458
#   }
#   relative_keypoints {
#     x: 0.40155693888664246
#     y: 0.48306864500045776
#   }
#   relative_keypoints {
#     x: 0.2864421308040619
#     y: 0.3976222276687622
#   }
#   relative_keypoints {
#     x: 0.4446682929992676
#     y: 0.39239025115966797
#   }
# }
#
# label_id: 0
# score: 0.963017463684082
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.273168683052063
#     ymin: 0.2617862820625305
#     width: 0.18142086267471313
#     height: 0.32252615690231323
#   }
#   relative_keypoints {
#     x: 0.34438902139663696
#     y: 0.3457157015800476
#   }
#   relative_keypoints {
#     x: 0.4224168360233307
#     y: 0.3488345742225647
#   }
#   relative_keypoints {
#     x: 0.3992908000946045
#     y: 0.4173735976219177
#   }
#   relative_keypoints {
#     x: 0.3929955065250397
#     y: 0.4855630397796631
#   }
#   relative_keypoints {
#     x: 0.27366673946380615
#     y: 0.38477110862731934
#   }
#   relative_keypoints {
#     x: 0.44179582595825195
#     y: 0.3824293613433838
#   }
# }
#
# label_id: 0
# score: 0.9763103723526001
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.27247676253318787
#     ymin: 0.2746655344963074
#     width: 0.16932561993598938
#     height: 0.30102312564849854
#   }
#   relative_keypoints {
#     x: 0.3313450515270233
#     y: 0.3516697883605957
#   }
#   relative_keypoints {
#     x: 0.41090893745422363
#     y: 0.3471977710723877
#   }
#   relative_keypoints {
#     x: 0.38602107763290405
#     y: 0.41215938329696655
#   }
#   relative_keypoints {
#     x: 0.38323354721069336
#     y: 0.4783761501312256
#   }
#   relative_keypoints {
#     x: 0.26777371764183044
#     y: 0.3999294638633728
#   }
#   relative_keypoints {
#     x: 0.43616804480552673
#     y: 0.38271206617355347
#   }
# }
#
# label_id: 0
# score: 0.968485951423645
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2581392526626587
#     ymin: 0.2555254101753235
#     width: 0.17933249473571777
#     height: 0.3188138008117676
#   }
#   relative_keypoints {
#     x: 0.3248351514339447
#     y: 0.34087932109832764
#   }
#   relative_keypoints {
#     x: 0.40225496888160706
#     y: 0.3315330743789673
#   }
#   relative_keypoints {
#     x: 0.3819522261619568
#     y: 0.4047732949256897
#   }
#   relative_keypoints {
#     x: 0.37889328598976135
#     y: 0.47326648235321045
#   }
#   relative_keypoints {
#     x: 0.25815773010253906
#     y: 0.3874480724334717
#   }
#   relative_keypoints {
#     x: 0.42600536346435547
#     y: 0.3606393337249756
#   }
# }
#
# label_id: 0
# score: 0.9660875797271729
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.255474716424942
#     ymin: 0.2753843069076538
#     width: 0.17126065492630005
#     height: 0.30446290969848633
#   }
#   relative_keypoints {
#     x: 0.3167155683040619
#     y: 0.3552175760269165
#   }
#   relative_keypoints {
#     x: 0.39400285482406616
#     y: 0.34646856784820557
#   }
#   relative_keypoints {
#     x: 0.37268996238708496
#     y: 0.4135315418243408
#   }
#   relative_keypoints {
#     x: 0.36962947249412537
#     y: 0.48148638010025024
#   }
#   relative_keypoints {
#     x: 0.2517315745353699
#     y: 0.40294235944747925
#   }
#   relative_keypoints {
#     x: 0.41831058263778687
#     y: 0.3772432208061218
#   }
# }
#
# label_id: 0
# score: 0.957646369934082
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.24530117213726044
#     ymin: 0.2754092216491699
#     width: 0.16818271577358246
#     height: 0.2989906072616577
#   }
#   relative_keypoints {
#     x: 0.3148653209209442
#     y: 0.34980064630508423
#   }
#   relative_keypoints {
#     x: 0.3838889002799988
#     y: 0.34916365146636963
#   }
#   relative_keypoints {
#     x: 0.3676385283470154
#     y: 0.41128355264663696
#   }
#   relative_keypoints {
#     x: 0.36151158809661865
#     y: 0.47930359840393066
#   }
#   relative_keypoints {
#     x: 0.24669170379638672
#     y: 0.3933446407318115
#   }
#   relative_keypoints {
#     x: 0.39948317408561707
#     y: 0.3831931948661804
#   }
# }
#
# label_id: 0
# score: 0.9436192512512207
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.24230839312076569
#     ymin: 0.26996296644210815
#     width: 0.1737213283777237
#     height: 0.30883699655532837
#   }
#   relative_keypoints {
#     x: 0.31366974115371704
#     y: 0.3473689556121826
#   }
#   relative_keypoints {
#     x: 0.385395884513855
#     y: 0.3460267186164856
#   }
#   relative_keypoints {
#     x: 0.36882346868515015
#     y: 0.408466100692749
#   }
#   relative_keypoints {
#     x: 0.36265742778778076
#     y: 0.4798871874809265
#   }
#   relative_keypoints {
#     x: 0.24293026328086853
#     y: 0.3951171040534973
#   }
#   relative_keypoints {
#     x: 0.4016013443470001
#     y: 0.38260704278945923
#   }
# }
#
# label_id: 0
# score: 0.9484489560127258
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.23609088361263275
#     ymin: 0.27129483222961426
#     width: 0.17153345048427582
#     height: 0.3049483299255371
#   }
#   relative_keypoints {
#     x: 0.3073687255382538
#     y: 0.34681153297424316
#   }
#   relative_keypoints {
#     x: 0.37746649980545044
#     y: 0.34080737829208374
#   }
#   relative_keypoints {
#     x: 0.3631037771701813
#     y: 0.40193629264831543
#   }
#   relative_keypoints {
#     x: 0.3585898280143738
#     y: 0.4744226932525635
#   }
#   relative_keypoints {
#     x: 0.23684145510196686
#     y: 0.403029203414917
#   }
#   relative_keypoints {
#     x: 0.39379751682281494
#     y: 0.37993621826171875
#   }
# }
#
# label_id: 0
# score: 0.9465261697769165
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2252592146396637
#     ymin: 0.26460087299346924
#     width: 0.17329594492912292
#     height: 0.3080812692642212
#   }
#   relative_keypoints {
#     x: 0.30019474029541016
#     y: 0.3493117094039917
#   }
#   relative_keypoints {
#     x: 0.37004685401916504
#     y: 0.3340069055557251
#   }
#   relative_keypoints {
#     x: 0.36137112975120544
#     y: 0.40220797061920166
#   }
#   relative_keypoints {
#     x: 0.357575923204422
#     y: 0.47238051891326904
#   }
#   relative_keypoints {
#     x: 0.22529426217079163
#     y: 0.40770334005355835
#   }
#   relative_keypoints {
#     x: 0.3817467987537384
#     y: 0.36641979217529297
#   }
# }
#
# label_id: 0
# score: 0.9474537968635559
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2180897295475006
#     ymin: 0.26653414964675903
#     width: 0.1758476197719574
#     height: 0.3126181960105896
#   }
#   relative_keypoints {
#     x: 0.2884068191051483
#     y: 0.3556337356567383
#   }
#   relative_keypoints {
#     x: 0.36050260066986084
#     y: 0.3348348140716553
#   }
#   relative_keypoints {
#     x: 0.34974318742752075
#     y: 0.4094906449317932
#   }
#   relative_keypoints {
#     x: 0.34919649362564087
#     y: 0.4801747798919678
#   }
#   relative_keypoints {
#     x: 0.21917611360549927
#     y: 0.4156697392463684
#   }
#   relative_keypoints {
#     x: 0.3786410987377167
#     y: 0.3624640703201294
#   }
# }
#
# label_id: 0
# score: 0.945172131061554
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2180740088224411
#     ymin: 0.25683003664016724
#     width: 0.17360930144786835
#     height: 0.30863845348358154
#   }
#   relative_keypoints {
#     x: 0.2865839898586273
#     y: 0.33875370025634766
#   }
#   relative_keypoints {
#     x: 0.35998472571372986
#     y: 0.31701457500457764
#   }
#   relative_keypoints {
#     x: 0.34794020652770996
#     y: 0.38315117359161377
#   }
#   relative_keypoints {
#     x: 0.34641116857528687
#     y: 0.45907866954803467
#   }
#   relative_keypoints {
#     x: 0.21630267798900604
#     y: 0.41086840629577637
#   }
#   relative_keypoints {
#     x: 0.37749651074409485
#     y: 0.3595191240310669
#   }
# }
#
# label_id: 0
# score: 0.9627014398574829
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2123875766992569
#     ymin: 0.25912827253341675
#     width: 0.17259295284748077
#     height: 0.30683207511901855
#   }
#   relative_keypoints {
#     x: 0.2765897512435913
#     y: 0.3452380895614624
#   }
#   relative_keypoints {
#     x: 0.35020363330841064
#     y: 0.3211638927459717
#   }
#   relative_keypoints {
#     x: 0.33662912249565125
#     y: 0.39289218187332153
#   }
#   relative_keypoints {
#     x: 0.3373587727546692
#     y: 0.4644067883491516
#   }
#   relative_keypoints {
#     x: 0.21174047887325287
#     y: 0.41051185131073
#   }
#   relative_keypoints {
#     x: 0.3722993731498718
#     y: 0.35306650400161743
#   }
# }
#
# label_id: 0
# score: 0.9745497107505798
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.20822438597679138
#     ymin: 0.2589763402938843
#     width: 0.1721634566783905
#     height: 0.3060683608055115
#   }
#   relative_keypoints {
#     x: 0.27500811219215393
#     y: 0.3451225161552429
#   }
#   relative_keypoints {
#     x: 0.34864696860313416
#     y: 0.32031577825546265
#   }
#   relative_keypoints {
#     x: 0.3378921151161194
#     y: 0.3922131061553955
#   }
#   relative_keypoints {
#     x: 0.3375059962272644
#     y: 0.4635329842567444
#   }
#   relative_keypoints {
#     x: 0.20568029582500458
#     y: 0.4121255874633789
#   }
#   relative_keypoints {
#     x: 0.3666014075279236
#     y: 0.3525393009185791
#   }
# }
#
# label_id: 0
# score: 0.9790000319480896
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.20868316292762756
#     ymin: 0.26862841844558716
#     width: 0.16637584567070007
#     height: 0.29577916860580444
#   }
#   relative_keypoints {
#     x: 0.27466508746147156
#     y: 0.351243793964386
#   }
#   relative_keypoints {
#     x: 0.34605374932289124
#     y: 0.328748881816864
#   }
#   relative_keypoints {
#     x: 0.33616721630096436
#     y: 0.3994043469429016
#   }
#   relative_keypoints {
#     x: 0.33503273129463196
#     y: 0.46749305725097656
#   }
#   relative_keypoints {
#     x: 0.20584990084171295
#     y: 0.413909912109375
#   }
#   relative_keypoints {
#     x: 0.36165428161621094
#     y: 0.3593899607658386
#   }
# }
#
# label_id: 0
# score: 0.9749956130981445
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.20856261253356934
#     ymin: 0.2642223834991455
#     width: 0.16805320978164673
#     height: 0.298761248588562
#   }
#   relative_keypoints {
#     x: 0.27321743965148926
#     y: 0.34679853916168213
#   }
#   relative_keypoints {
#     x: 0.3464658558368683
#     y: 0.3237501382827759
#   }
#   relative_keypoints {
#     x: 0.33486467599868774
#     y: 0.39446598291397095
#   }
#   relative_keypoints {
#     x: 0.3341202437877655
#     y: 0.46391695737838745
#   }
#   relative_keypoints {
#     x: 0.2050231546163559
#     y: 0.41127485036849976
#   }
#   relative_keypoints {
#     x: 0.36421629786491394
#     y: 0.3558495044708252
#   }
# }
# label_id: 0
# score: 0.9771077632904053
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.20794427394866943
#     ymin: 0.2621108293533325
#     width: 0.16907653212547302
#     height: 0.30058056116104126
#   }
#   relative_keypoints {
#     x: 0.27267903089523315
#     y: 0.3463348150253296
#   }
#   relative_keypoints {
#     x: 0.3461667001247406
#     y: 0.3214167356491089
#   }
#   relative_keypoints {
#     x: 0.33500972390174866
#     y: 0.394126832485199
#   }
#   relative_keypoints {
#     x: 0.3348374664783478
#     y: 0.46369755268096924
#   }
#   relative_keypoints {
#     x: 0.20467129349708557
#     y: 0.4118812084197998
#   }
#   relative_keypoints {
#     x: 0.3643627166748047
#     y: 0.35221242904663086
#   }
# }
#
# label_id: 0
# score: 0.9677942395210266
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.20337408781051636
#     ymin: 0.24934744834899902
#     width: 0.177684485912323
#     height: 0.31588417291641235
#   }
#   relative_keypoints {
#     x: 0.27022305130958557
#     y: 0.3403233289718628
#   }
#   relative_keypoints {
#     x: 0.34717848896980286
#     y: 0.31932735443115234
#   }
#   relative_keypoints {
#     x: 0.333117812871933
#     y: 0.39565932750701904
#   }
#   relative_keypoints {
#     x: 0.33251574635505676
#     y: 0.4650615453720093
#   }
#   relative_keypoints {
#     x: 0.20136971771717072
#     y: 0.39812225103378296
#   }
#   relative_keypoints {
#     x: 0.3681057393550873
#     y: 0.3454429507255554
#   }
# }
#
# label_id: 0
# score: 0.9595680236816406
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.20518441498279572
#     ymin: 0.24835020303726196
#     width: 0.1733465939760208
#     height: 0.3081725835800171
#   }
#   relative_keypoints {
#     x: 0.2740437984466553
#     y: 0.33305180072784424
#   }
#   relative_keypoints {
#     x: 0.3476581573486328
#     y: 0.3183963894844055
#   }
#   relative_keypoints {
#     x: 0.33421847224235535
#     y: 0.38976913690567017
#   }
#   relative_keypoints {
#     x: 0.3317035138607025
#     y: 0.45809173583984375
#   }
#   relative_keypoints {
#     x: 0.20446373522281647
#     y: 0.3875189423561096
#   }
#   relative_keypoints {
#     x: 0.3649260103702545
#     y: 0.3476579189300537
#   }
# }
#
# label_id: 0
# score: 0.9598629474639893
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.20820651948451996
#     ymin: 0.2445603609085083
#     width: 0.17347709834575653
#     height: 0.3084040880203247
#   }
#   relative_keypoints {
#     x: 0.2800201177597046
#     y: 0.32761961221694946
#   }
#   relative_keypoints {
#     x: 0.35393157601356506
#     y: 0.31151098012924194
#   }
#   relative_keypoints {
#     x: 0.34386274218559265
#     y: 0.3803168535232544
#   }
#   relative_keypoints {
#     x: 0.34109747409820557
#     y: 0.45190781354904175
#   }
#   relative_keypoints {
#     x: 0.205696240067482
#     y: 0.39139246940612793
#   }
#   relative_keypoints {
#     x: 0.36706817150115967
#     y: 0.34584176540374756
#   }
# }
#
# label_id: 0
# score: 0.9311509728431702
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.21544413268566132
#     ymin: 0.2461146116256714
#     width: 0.1670697182416916
#     height: 0.29701268672943115
#   }
#   relative_keypoints {
#     x: 0.28592216968536377
#     y: 0.32793372869491577
#   }
#   relative_keypoints {
#     x: 0.3549606204032898
#     y: 0.3081117272377014
#   }
#   relative_keypoints {
#     x: 0.34717118740081787
#     y: 0.3766443133354187
#   }
#   relative_keypoints {
#     x: 0.3443569540977478
#     y: 0.44617706537246704
#   }
#   relative_keypoints {
#     x: 0.21390178799629211
#     y: 0.39061933755874634
#   }
#   relative_keypoints {
#     x: 0.36611706018447876
#     y: 0.3411760926246643
#   }
# }
#
# label_id: 0
# score: 0.9397187232971191
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2184727042913437
#     ymin: 0.24413931369781494
#     width: 0.17165584862232208
#     height: 0.3051658868789673
#   }
#   relative_keypoints {
#     x: 0.28732311725616455
#     y: 0.33533036708831787
#   }
#   relative_keypoints {
#     x: 0.358573317527771
#     y: 0.31149935722351074
#   }
#   relative_keypoints {
#     x: 0.34826236963272095
#     y: 0.38776272535324097
#   }
#   relative_keypoints {
#     x: 0.3471955358982086
#     y: 0.4544975757598877
#   }
#   relative_keypoints {
#     x: 0.21855047345161438
#     y: 0.3917820453643799
#   }
#   relative_keypoints {
#     x: 0.37543684244155884
#     y: 0.33551526069641113
#   }
# }
#
# label_id: 0
# score: 0.9064059853553772
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.22497519850730896
#     ymin: 0.23358452320098877
#     width: 0.1731383204460144
#     height: 0.30780184268951416
#   }
#   relative_keypoints {
#     x: 0.29873332381248474
#     y: 0.31548774242401123
#   }
#   relative_keypoints {
#     x: 0.3684355318546295
#     y: 0.30355143547058105
#   }
#   relative_keypoints {
#     x: 0.3569786846637726
#     y: 0.3721628189086914
#   }
#   relative_keypoints {
#     x: 0.3518242835998535
#     y: 0.4430478811264038
#   }
#   relative_keypoints {
#     x: 0.2250695675611496
#     y: 0.37068700790405273
#   }
#   relative_keypoints {
#     x: 0.38057926297187805
#     y: 0.3392032980918884
#   }
# }
#
# label_id: 0
# score: 0.9320518374443054
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.23184145987033844
#     ymin: 0.24167388677597046
#     width: 0.16531561315059662
#     height: 0.29389488697052
#   }
#   relative_keypoints {
#     x: 0.30353403091430664
#     y: 0.3180456757545471
#   }
#   relative_keypoints {
#     x: 0.3704492449760437
#     y: 0.3010357618331909
#   }
#   relative_keypoints {
#     x: 0.3630863428115845
#     y: 0.3648677468299866
#   }
#   relative_keypoints {
#     x: 0.35951873660087585
#     y: 0.4358423352241516
#   }
#   relative_keypoints {
#     x: 0.23033180832862854
#     y: 0.38548511266708374
#   }
#   relative_keypoints {
#     x: 0.3802102208137512
#     y: 0.3421863317489624
#   }
# }
#
# label_id: 0
# score: 0.952167272567749
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.23133927583694458
#     ymin: 0.22965729236602783
#     width: 0.17711779475212097
#     height: 0.31487590074539185
#   }
#   relative_keypoints {
#     x: 0.3064712584018707
#     y: 0.3144950866699219
#   }
#   relative_keypoints {
#     x: 0.3781515657901764
#     y: 0.29852086305618286
#   }
#   relative_keypoints {
#     x: 0.3674345016479492
#     y: 0.37119442224502563
#   }
#   relative_keypoints {
#     x: 0.3639351427555084
#     y: 0.4428579807281494
#   }
#   relative_keypoints {
#     x: 0.23282848298549652
#     y: 0.37482523918151855
#   }
#   relative_keypoints {
#     x: 0.39168232679367065
#     y: 0.33438563346862793
#   }
# }
#
# label_id: 0
# score: 0.9491020441055298
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2361745834350586
#     ymin: 0.22233939170837402
#     width: 0.18211570382118225
#     height: 0.32376134395599365
#   }
#   relative_keypoints {
#     x: 0.3106030523777008
#     y: 0.3115178942680359
#   }
#   relative_keypoints {
#     x: 0.38362225890159607
#     y: 0.2984793186187744
#   }
#   relative_keypoints {
#     x: 0.36932411789894104
#     y: 0.37442272901535034
#   }
#   relative_keypoints {
#     x: 0.36581531167030334
#     y: 0.4449527859687805
#   }
#   relative_keypoints {
#     x: 0.24038094282150269
#     y: 0.3646315336227417
#   }
#   relative_keypoints {
#     x: 0.40103641152381897
#     y: 0.33153557777404785
#   }
# }
#
# label_id: 0
# score: 0.9653285145759583
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.24472109973430634
#     ymin: 0.22281396389007568
#     width: 0.18033789098262787
#     height: 0.3206014037132263
#   }
#   relative_keypoints {
#     x: 0.32047930359840393
#     y: 0.3049857020378113
#   }
#   relative_keypoints {
#     x: 0.3922152817249298
#     y: 0.30388617515563965
#   }
#   relative_keypoints {
#     x: 0.3749617338180542
#     y: 0.3739416003227234
#   }
#   relative_keypoints {
#     x: 0.3677310347557068
#     y: 0.4418145418167114
#   }
#   relative_keypoints {
#     x: 0.25012606382369995
#     y: 0.34754955768585205
#   }
#   relative_keypoints {
#     x: 0.40724119544029236
#     y: 0.3417968153953552
#   }
# }
#
# label_id: 0
# score: 0.9601668119430542
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.25671741366386414
#     ymin: 0.23072338104248047
#     width: 0.1760852038860321
#     height: 0.3130413889884949
#   }
#   relative_keypoints {
#     x: 0.3275303542613983
#     y: 0.31647592782974243
#   }
#   relative_keypoints {
#     x: 0.400802344083786
#     y: 0.30762386322021484
#   }
#   relative_keypoints {
#     x: 0.38481417298316956
#     y: 0.3811626434326172
#   }
#   relative_keypoints {
#     x: 0.3805220127105713
#     y: 0.446142315864563
#   }
#   relative_keypoints {
#     x: 0.2587329149246216
#     y: 0.36187976598739624
#   }
#   relative_keypoints {
#     x: 0.4180818200111389
#     y: 0.33725816011428833
#   }
# }
# label_id: 0
# score: 0.9644055962562561
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.26263687014579773
#     ymin: 0.22828435897827148
#     width: 0.18048512935638428
#     height: 0.32086366415023804
#   }
#   relative_keypoints {
#     x: 0.32947757840156555
#     y: 0.3190547227859497
#   }
#   relative_keypoints {
#     x: 0.40822991728782654
#     y: 0.3074139952659607
#   }
#   relative_keypoints {
#     x: 0.388960063457489
#     y: 0.3847196698188782
#   }
#   relative_keypoints {
#     x: 0.38738131523132324
#     y: 0.45017653703689575
#   }
#   relative_keypoints {
#     x: 0.2629154920578003
#     y: 0.36449670791625977
#   }
#   relative_keypoints {
#     x: 0.43276017904281616
#     y: 0.3310179114341736
#   }
# }
#
# label_id: 0
# score: 0.9515295028686523
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2663504481315613
#     ymin: 0.22538542747497559
#     width: 0.1846923828125
#     height: 0.3283422589302063
#   }
#   relative_keypoints {
#     x: 0.3446618616580963
#     y: 0.3166468143463135
#   }
#   relative_keypoints {
#     x: 0.4207242429256439
#     y: 0.3102925419807434
#   }
#   relative_keypoints {
#     x: 0.4056590497493744
#     y: 0.3861430287361145
#   }
#   relative_keypoints {
#     x: 0.3995562791824341
#     y: 0.4540090560913086
#   }
#   relative_keypoints {
#     x: 0.267813116312027
#     y: 0.359855592250824
#   }
#   relative_keypoints {
#     x: 0.4345096945762634
#     y: 0.33895784616470337
#   }
# }
#
# label_id: 0
# score: 0.9395546317100525
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.27436363697052
#     ymin: 0.22271370887756348
#     width: 0.18610495328903198
#     height: 0.3308536410331726
#   }
#   relative_keypoints {
#     x: 0.3421081602573395
#     y: 0.3264530897140503
#   }
#   relative_keypoints {
#     x: 0.42067578434944153
#     y: 0.3103887438774109
#   }
#   relative_keypoints {
#     x: 0.40038150548934937
#     y: 0.39764469861984253
#   }
#   relative_keypoints {
#     x: 0.40026089549064636
#     y: 0.46064919233322144
#   }
#   relative_keypoints {
#     x: 0.2774410545825958
#     y: 0.36572492122650146
#   }
#   relative_keypoints {
#     x: 0.4473627507686615
#     y: 0.32401788234710693
#   }
# }
#
# label_id: 0
# score: 0.9038052558898926
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.28756049275398254
#     ymin: 0.23162060976028442
#     width: 0.17807546257972717
#     height: 0.3165791630744934
#   }
#   relative_keypoints {
#     x: 0.34569916129112244
#     y: 0.3321669101715088
#   }
#   relative_keypoints {
#     x: 0.42164453864097595
#     y: 0.3152902126312256
#   }
#   relative_keypoints {
#     x: 0.396944135427475
#     y: 0.397739052772522
#   }
#   relative_keypoints {
#     x: 0.399020254611969
#     y: 0.4586918354034424
#   }
#   relative_keypoints {
#     x: 0.2917034327983856
#     y: 0.37177085876464844
#   }
#   relative_keypoints {
#     x: 0.4551149308681488
#     y: 0.33094680309295654
#   }
# }
#
# label_id: 0
# score: 0.928486168384552
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2862173616886139
#     ymin: 0.24090415239334106
#     width: 0.1749957799911499
#     height: 0.31110405921936035
#   }
#   relative_keypoints {
#     x: 0.33962297439575195
#     y: 0.34676992893218994
#   }
#   relative_keypoints {
#     x: 0.41246333718299866
#     y: 0.3250093460083008
#   }
#   relative_keypoints {
#     x: 0.3881179392337799
#     y: 0.4154732823371887
#   }
#   relative_keypoints {
#     x: 0.3933265507221222
#     y: 0.4700626730918884
#   }
#   relative_keypoints {
#     x: 0.29407361149787903
#     y: 0.37839049100875854
#   }
#   relative_keypoints {
#     x: 0.45016536116600037
#     y: 0.32761889696121216
#   }
# }
#
# label_id: 0
# score: 0.9141365885734558
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.28424233198165894
#     ymin: 0.23964500427246094
#     width: 0.18144237995147705
#     height: 0.3225638270378113
#   }
#   relative_keypoints {
#     x: 0.34029391407966614
#     y: 0.3543093204498291
#   }
#   relative_keypoints {
#     x: 0.4151986837387085
#     y: 0.3330766558647156
#   }
#   relative_keypoints {
#     x: 0.38888978958129883
#     y: 0.42798739671707153
#   }
#   relative_keypoints {
#     x: 0.39287900924682617
#     y: 0.481606662273407
#   }
#   relative_keypoints {
#     x: 0.292511522769928
#     y: 0.37612009048461914
#   }
#   relative_keypoints {
#     x: 0.45384472608566284
#     y: 0.3291621804237366
#   }
# }
#
# label_id: 0
# score: 0.9341433048248291
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.29056474566459656
#     ymin: 0.24852526187896729
#     width: 0.17926561832427979
#     height: 0.31869471073150635
#   }
#   relative_keypoints {
#     x: 0.34734228253364563
#     y: 0.35504037141799927
#   }
#   relative_keypoints {
#     x: 0.41969993710517883
#     y: 0.3294423222541809
#   }
#   relative_keypoints {
#     x: 0.39763498306274414
#     y: 0.4189636707305908
#   }
#   relative_keypoints {
#     x: 0.4027315080165863
#     y: 0.4792720079421997
#   }
#   relative_keypoints {
#     x: 0.2998974919319153
#     y: 0.39573198556900024
#   }
#   relative_keypoints {
#     x: 0.45679014921188354
#     y: 0.33861327171325684
#   }
# }
#
# label_id: 0
# score: 0.9416497945785522
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2936249375343323
#     ymin: 0.2521064281463623
#     width: 0.18001359701156616
#     height: 0.32002460956573486
#   }
#   relative_keypoints {
#     x: 0.35619866847991943
#     y: 0.3526589870452881
#   }
#   relative_keypoints {
#     x: 0.4280652403831482
#     y: 0.34168845415115356
#   }
#   relative_keypoints {
#     x: 0.4049378037452698
#     y: 0.4262769818305969
#   }
#   relative_keypoints {
#     x: 0.40523168444633484
#     y: 0.48513758182525635
#   }
#   relative_keypoints {
#     x: 0.3027799427509308
#     y: 0.3821507692337036
#   }
#   relative_keypoints {
#     x: 0.4585282802581787
#     y: 0.354093074798584
#   }
# }
#
# label_id: 0
# score: 0.9450181126594543
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3064780831336975
#     ymin: 0.2550230622291565
#     width: 0.17339929938316345
#     height: 0.30826520919799805
#   }
#   relative_keypoints {
#     x: 0.3625926673412323
#     y: 0.35266345739364624
#   }
#   relative_keypoints {
#     x: 0.4323844909667969
#     y: 0.3392398953437805
#   }
#   relative_keypoints {
#     x: 0.40777868032455444
#     y: 0.422424852848053
#   }
#   relative_keypoints {
#     x: 0.40946847200393677
#     y: 0.47968167066574097
#   }
#   relative_keypoints {
#     x: 0.31529873609542847
#     y: 0.38182806968688965
#   }
#   relative_keypoints {
#     x: 0.46670231223106384
#     y: 0.3509399890899658
#   }
# }
#
# label_id: 0
# score: 0.9487535953521729
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3035159707069397
#     ymin: 0.2524593472480774
#     width: 0.1775226891040802
#     height: 0.3155955672264099
#   }
#   relative_keypoints {
#     x: 0.36673644185066223
#     y: 0.35152947902679443
#   }
#   relative_keypoints {
#     x: 0.437828928232193
#     y: 0.34613335132598877
#   }
#   relative_keypoints {
#     x: 0.4131641387939453
#     y: 0.43108391761779785
#   }
#   relative_keypoints {
#     x: 0.4108215570449829
#     y: 0.48567163944244385
#   }
#   relative_keypoints {
#     x: 0.31155139207839966
#     y: 0.3682907819747925
#   }
#   relative_keypoints {
#     x: 0.466299831867218
#     y: 0.35449230670928955
#   }
# }
#
# label_id: 0
# score: 0.9537248611450195
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3131246566772461
#     ymin: 0.2680453658103943
#     width: 0.17295688390731812
#     height: 0.307478666305542
#   }
#   relative_keypoints {
#     x: 0.37424376606941223
#     y: 0.3602990508079529
#   }
#   relative_keypoints {
#     x: 0.4447953701019287
#     y: 0.3596816658973694
#   }
#   relative_keypoints {
#     x: 0.4196030795574188
#     y: 0.4392722249031067
#   }
#   relative_keypoints {
#     x: 0.4164998233318329
#     y: 0.4931652545928955
#   }
#   relative_keypoints {
#     x: 0.31991419196128845
#     y: 0.37625449895858765
#   }
#   relative_keypoints {
#     x: 0.47274523973464966
#     y: 0.37028151750564575
#   }
# }
#
# label_id: 0
# score: 0.9366628527641296
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.32772761583328247
#     ymin: 0.26591718196868896
#     width: 0.16922158002853394
#     height: 0.30083876848220825
#   }
#   relative_keypoints {
#     x: 0.3733123540878296
#     y: 0.3671499490737915
#   }
#   relative_keypoints {
#     x: 0.44312670826911926
#     y: 0.35171324014663696
#   }
#   relative_keypoints {
#     x: 0.4122621417045593
#     y: 0.4411003589630127
#   }
#   relative_keypoints {
#     x: 0.4171905219554901
#     y: 0.49146926403045654
#   }
#   relative_keypoints {
#     x: 0.33722618222236633
#     y: 0.3840009570121765
#   }
#   relative_keypoints {
#     x: 0.4883943498134613
#     y: 0.35000526905059814
#   }
# }
#
# label_id: 0
# score: 0.9619210958480835
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.32164931297302246
#     ymin: 0.26119810342788696
#     width: 0.18458348512649536
#     height: 0.3281482458114624
#   }
#   relative_keypoints {
#     x: 0.37355852127075195
#     y: 0.37155306339263916
#   }
#   relative_keypoints {
#     x: 0.44955453276634216
#     y: 0.3624102473258972
#   }
#   relative_keypoints {
#     x: 0.4146192669868469
#     y: 0.4583315849304199
#   }
#   relative_keypoints {
#     x: 0.41792207956314087
#     y: 0.509978711605072
#   }
#   relative_keypoints {
#     x: 0.3334529995918274
#     y: 0.38215136528015137
#   }
#   relative_keypoints {
#     x: 0.4963291585445404
#     y: 0.36177992820739746
#   }
# }
# label_id: 0
# score: 0.9397076964378357
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3259935975074768
#     ymin: 0.2665700912475586
#     width: 0.18405967950820923
#     height: 0.3272168040275574
#   }
#   relative_keypoints {
#     x: 0.38293468952178955
#     y: 0.37169718742370605
#   }
#   relative_keypoints {
#     x: 0.4621473550796509
#     y: 0.37209463119506836
#   }
#   relative_keypoints {
#     x: 0.4259040355682373
#     y: 0.46087437868118286
#   }
#   relative_keypoints {
#     x: 0.42381954193115234
#     y: 0.5129135847091675
#   }
#   relative_keypoints {
#     x: 0.33234402537345886
#     y: 0.37455976009368896
#   }
#   relative_keypoints {
#     x: 0.5016719102859497
#     y: 0.3753836154937744
#   }
# }
#
# label_id: 0
# score: 0.9552885890007019
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3298419117927551
#     ymin: 0.27001190185546875
#     width: 0.18854820728302002
#     height: 0.3351971507072449
#   }
#   relative_keypoints {
#     x: 0.39159584045410156
#     y: 0.3781709671020508
#   }
#   relative_keypoints {
#     x: 0.4717525839805603
#     y: 0.3785165548324585
#   }
#   relative_keypoints {
#     x: 0.43948718905448914
#     y: 0.470272421836853
#   }
#   relative_keypoints {
#     x: 0.437939316034317
#     y: 0.5231110453605652
#   }
#   relative_keypoints {
#     x: 0.33672910928726196
#     y: 0.38540011644363403
#   }
#   relative_keypoints {
#     x: 0.5076090097427368
#     y: 0.38008129596710205
#   }
# }
#
# label_id: 0
# score: 0.9415298104286194
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.33471161127090454
#     ymin: 0.27324366569519043
#     width: 0.18585622310638428
#     height: 0.330411434173584
#   }
#   relative_keypoints {
#     x: 0.3951132595539093
#     y: 0.38119566440582275
#   }
#   relative_keypoints {
#     x: 0.4733670949935913
#     y: 0.38361912965774536
#   }
#   relative_keypoints {
#     x: 0.44045329093933105
#     y: 0.47294604778289795
#   }
#   relative_keypoints {
#     x: 0.4388905465602875
#     y: 0.5238596796989441
#   }
#   relative_keypoints {
#     x: 0.34247973561286926
#     y: 0.38500094413757324
#   }
#   relative_keypoints {
#     x: 0.509880781173706
#     y: 0.3832661509513855
#   }
# }
#
# label_id: 0
# score: 0.9400142431259155
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.33940041065216064
#     ymin: 0.2654907703399658
#     width: 0.19079381227493286
#     height: 0.33918970823287964
#   }
#   relative_keypoints {
#     x: 0.3941080570220947
#     y: 0.3820868134498596
#   }
#   relative_keypoints {
#     x: 0.47385814785957336
#     y: 0.3762654662132263
#   }
#   relative_keypoints {
#     x: 0.43731847405433655
#     y: 0.47360938787460327
#   }
#   relative_keypoints {
#     x: 0.4401209354400635
#     y: 0.5237674713134766
#   }
#   relative_keypoints {
#     x: 0.35088077187538147
#     y: 0.38746535778045654
#   }
#   relative_keypoints {
#     x: 0.520372748374939
#     y: 0.37040072679519653
#   }
# }
#
# label_id: 0
# score: 0.9314985871315002
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.33928754925727844
#     ymin: 0.26664483547210693
#     width: 0.19107726216316223
#     height: 0.33969366550445557
#   }
#   relative_keypoints {
#     x: 0.39582201838493347
#     y: 0.3797960877418518
#   }
#   relative_keypoints {
#     x: 0.4763513505458832
#     y: 0.3814055919647217
#   }
#   relative_keypoints {
#     x: 0.4389491081237793
#     y: 0.4765756130218506
#   }
#   relative_keypoints {
#     x: 0.43964725732803345
#     y: 0.5270587205886841
#   }
#   relative_keypoints {
#     x: 0.3492700755596161
#     y: 0.3806300759315491
#   }
#   relative_keypoints {
#     x: 0.5206884145736694
#     y: 0.37722939252853394
#   }
# }
#
# label_id: 0
# score: 0.938828706741333
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3440213203430176
#     ymin: 0.2775691747665405
#     width: 0.1867443323135376
#     height: 0.3319905996322632
#   }
#   relative_keypoints {
#     x: 0.39420178532600403
#     y: 0.3866327404975891
#   }
#   relative_keypoints {
#     x: 0.47451943159103394
#     y: 0.3855821490287781
#   }
#   relative_keypoints {
#     x: 0.435057133436203
#     y: 0.4773695468902588
#   }
#   relative_keypoints {
#     x: 0.4378163516521454
#     y: 0.5286681652069092
#   }
#   relative_keypoints {
#     x: 0.35303008556365967
#     y: 0.39224231243133545
#   }
#   relative_keypoints {
#     x: 0.5239061117172241
#     y: 0.38383346796035767
#   }
# }
#
# label_id: 0
# score: 0.9406092166900635
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3452521860599518
#     ymin: 0.2834015488624573
#     width: 0.18883094191551208
#     height: 0.33570027351379395
#   }
#   relative_keypoints {
#     x: 0.4003562927246094
#     y: 0.38495326042175293
#   }
#   relative_keypoints {
#     x: 0.4824783504009247
#     y: 0.39571940898895264
#   }
#   relative_keypoints {
#     x: 0.44125181436538696
#     y: 0.4824128746986389
#   }
#   relative_keypoints {
#     x: 0.4396496117115021
#     y: 0.5359295606613159
#   }
#   relative_keypoints {
#     x: 0.35191646218299866
#     y: 0.3848525285720825
#   }
#   relative_keypoints {
#     x: 0.5271934866905212
#     y: 0.40179502964019775
#   }
# }
#
# label_id: 0
# score: 0.9469974040985107
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34339797496795654
#     ymin: 0.28985095024108887
#     width: 0.18879330158233643
#     height: 0.3356330990791321
#   }
#   relative_keypoints {
#     x: 0.39512839913368225
#     y: 0.38934046030044556
#   }
#   relative_keypoints {
#     x: 0.480119526386261
#     y: 0.3982656002044678
#   }
#   relative_keypoints {
#     x: 0.4362981617450714
#     y: 0.4836474061012268
#   }
#   relative_keypoints {
#     x: 0.43574830889701843
#     y: 0.5387358069419861
#   }
#   relative_keypoints {
#     x: 0.34798121452331543
#     y: 0.39445096254348755
#   }
#   relative_keypoints {
#     x: 0.5278774499893188
#     y: 0.4080572724342346
#   }
# }
#
# label_id: 0
# score: 0.9513079524040222
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34646618366241455
#     ymin: 0.2980993390083313
#     width: 0.18399488925933838
#     height: 0.32710254192352295
#   }
#   relative_keypoints {
#     x: 0.3976919651031494
#     y: 0.39733344316482544
#   }
#   relative_keypoints {
#     x: 0.4798785448074341
#     y: 0.40327101945877075
#   }
#   relative_keypoints {
#     x: 0.4394623339176178
#     y: 0.48864489793777466
#   }
#   relative_keypoints {
#     x: 0.4395197927951813
#     y: 0.541418731212616
#   }
#   relative_keypoints {
#     x: 0.35077565908432007
#     y: 0.40283048152923584
#   }
#   relative_keypoints {
#     x: 0.5255023241043091
#     y: 0.4092891216278076
#   }
# }
#
# label_id: 0
# score: 0.9323278665542603
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3421831727027893
#     ymin: 0.29614877700805664
#     width: 0.1889316439628601
#     height: 0.33587902784347534
#   }
#   relative_keypoints {
#     x: 0.3944077491760254
#     y: 0.4087241291999817
#   }
#   relative_keypoints {
#     x: 0.47685185074806213
#     y: 0.4141392707824707
#   }
#   relative_keypoints {
#     x: 0.43621233105659485
#     y: 0.5101947784423828
#   }
#   relative_keypoints {
#     x: 0.43649929761886597
#     y: 0.5577199459075928
#   }
#   relative_keypoints {
#     x: 0.3484352231025696
#     y: 0.39935892820358276
#   }
#   relative_keypoints {
#     x: 0.524333119392395
#     y: 0.4032973051071167
#   }
# }
#
# label_id: 0
# score: 0.9577280879020691
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.33032751083374023
#     ymin: 0.28252869844436646
#     width: 0.19703662395477295
#     height: 0.3502870798110962
#   }
#   relative_keypoints {
#     x: 0.38621580600738525
#     y: 0.3965558409690857
#   }
#   relative_keypoints {
#     x: 0.47166991233825684
#     y: 0.400424063205719
#   }
#   relative_keypoints {
#     x: 0.42957744002342224
#     y: 0.49726253747940063
#   }
#   relative_keypoints {
#     x: 0.4297546148300171
#     y: 0.5493772029876709
#   }
#   relative_keypoints {
#     x: 0.33831149339675903
#     y: 0.3939979076385498
#   }
#   relative_keypoints {
#     x: 0.5200116634368896
#     y: 0.3975616693496704
#   }
# }
#
# label_id: 0
# score: 0.9605234861373901
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.32535412907600403
#     ymin: 0.2881094217300415
#     width: 0.19039228558540344
#     height: 0.33847469091415405
#   }
#   relative_keypoints {
#     x: 0.37832754850387573
#     y: 0.39558374881744385
#   }
#   relative_keypoints {
#     x: 0.46215254068374634
#     y: 0.39722198247909546
#   }
#   relative_keypoints {
#     x: 0.42225614190101624
#     y: 0.4896678924560547
#   }
#   relative_keypoints {
#     x: 0.4228309094905853
#     y: 0.5441358089447021
#   }
#   relative_keypoints {
#     x: 0.33101460337638855
#     y: 0.39919841289520264
#   }
#   relative_keypoints {
#     x: 0.5102344751358032
#     y: 0.3974111080169678
#   }
# }
#
# label_id: 0
# score: 0.9613898396492004
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3244331479072571
#     ymin: 0.2844574451446533
#     width: 0.1851181983947754
#     height: 0.32909995317459106
#   }
#   relative_keypoints {
#     x: 0.3801436722278595
#     y: 0.38274091482162476
#   }
#   relative_keypoints {
#     x: 0.4608120322227478
#     y: 0.39155930280685425
#   }
#   relative_keypoints {
#     x: 0.4216260015964508
#     y: 0.47868579626083374
#   }
#   relative_keypoints {
#     x: 0.4188730716705322
#     y: 0.5317574739456177
#   }
#   relative_keypoints {
#     x: 0.3304193615913391
#     y: 0.3822300434112549
#   }
#   relative_keypoints {
#     x: 0.5028852224349976
#     y: 0.39878302812576294
#   }
# }
# label_id: 0
# score: 0.9639363884925842
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.31944382190704346
#     ymin: 0.2747213840484619
#     width: 0.1904410719871521
#     height: 0.3385620713233948
#   }
#   relative_keypoints {
#     x: 0.37573057413101196
#     y: 0.37480199337005615
#   }
#   relative_keypoints {
#     x: 0.4562922716140747
#     y: 0.3882595896720886
#   }
#   relative_keypoints {
#     x: 0.4133569598197937
#     y: 0.47621119022369385
#   }
#   relative_keypoints {
#     x: 0.4104959964752197
#     y: 0.5292408466339111
#   }
#   relative_keypoints {
#     x: 0.3295246660709381
#     y: 0.37176376581192017
#   }
#   relative_keypoints {
#     x: 0.501740038394928
#     y: 0.3983520269393921
#   }
# }
#
# label_id: 0
# score: 0.9740607142448425
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.31723934412002563
#     ymin: 0.2851962447166443
#     width: 0.17902833223342896
#     height: 0.31827372312545776
#   }
#   relative_keypoints {
#     x: 0.3720536530017853
#     y: 0.3761056065559387
#   }
#   relative_keypoints {
#     x: 0.44892990589141846
#     y: 0.3911513686180115
#   }
#   relative_keypoints {
#     x: 0.40870586037635803
#     y: 0.472445547580719
#   }
#   relative_keypoints {
#     x: 0.4049268960952759
#     y: 0.5214391350746155
#   }
#   relative_keypoints {
#     x: 0.32566502690315247
#     y: 0.3718401789665222
#   }
#   relative_keypoints {
#     x: 0.4887942969799042
#     y: 0.40301668643951416
#   }
# }
#
# label_id: 0
# score: 0.9681441783905029
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.31739380955696106
#     ymin: 0.2732836604118347
#     width: 0.17590168118476868
#     height: 0.3127145767211914
#   }
#   relative_keypoints {
#     x: 0.3674394190311432
#     y: 0.3731038570404053
#   }
#   relative_keypoints {
#     x: 0.44076594710350037
#     y: 0.37584006786346436
#   }
#   relative_keypoints {
#     x: 0.4033561646938324
#     y: 0.4634954333305359
#   }
#   relative_keypoints {
#     x: 0.40315407514572144
#     y: 0.5100784301757812
#   }
#   relative_keypoints {
#     x: 0.3270069360733032
#     y: 0.37067341804504395
#   }
#   relative_keypoints {
#     x: 0.48435258865356445
#     y: 0.376700758934021
#   }
# }
#
# label_id: 0
# score: 0.9711005091667175
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.30981120467185974
#     ymin: 0.2690185308456421
#     width: 0.18005621433258057
#     height: 0.32010000944137573
#   }
#   relative_keypoints {
#     x: 0.3639945983886719
#     y: 0.3701751232147217
#   }
#   relative_keypoints {
#     x: 0.43713870644569397
#     y: 0.3702598810195923
#   }
#   relative_keypoints {
#     x: 0.4024159908294678
#     y: 0.4594762325286865
#   }
#   relative_keypoints {
#     x: 0.4030008018016815
#     y: 0.5102310180664062
#   }
#   relative_keypoints {
#     x: 0.32162222266197205
#     y: 0.374717652797699
#   }
#   relative_keypoints {
#     x: 0.4796903729438782
#     y: 0.3726165294647217
#   }
# }
#
# label_id: 0
# score: 0.9679553508758545
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3069801330566406
#     ymin: 0.26637786626815796
#     width: 0.1759214699268341
#     height: 0.3127487897872925
#   }
#   relative_keypoints {
#     x: 0.3602324426174164
#     y: 0.3630654811859131
#   }
#   relative_keypoints {
#     x: 0.4336342513561249
#     y: 0.36720359325408936
#   }
#   relative_keypoints {
#     x: 0.3976704180240631
#     y: 0.45107710361480713
#   }
#   relative_keypoints {
#     x: 0.3962043821811676
#     y: 0.5008449554443359
#   }
#   relative_keypoints {
#     x: 0.3159961998462677
#     y: 0.36536598205566406
#   }
#   relative_keypoints {
#     x: 0.47331976890563965
#     y: 0.3734700679779053
#   }
# }
#
# label_id: 0
# score: 0.9594053030014038
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2920251488685608
#     ymin: 0.2546399235725403
#     width: 0.1879938840866089
#     height: 0.33421146869659424
#   }
#   relative_keypoints {
#     x: 0.3617657423019409
#     y: 0.3570702075958252
#   }
#   relative_keypoints {
#     x: 0.43661564588546753
#     y: 0.3654063940048218
#   }
#   relative_keypoints {
#     x: 0.40471792221069336
#     y: 0.4528946280479431
#   }
#   relative_keypoints {
#     x: 0.3982909917831421
#     y: 0.505662202835083
#   }
#   relative_keypoints {
#     x: 0.30192989110946655
#     y: 0.35338228940963745
#   }
#   relative_keypoints {
#     x: 0.465802401304245
#     y: 0.37032169103622437
#   }
# }
#
# label_id: 0
# score: 0.9560235142707825
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.28563177585601807
#     ymin: 0.24913513660430908
#     width: 0.1910020411014557
#     height: 0.33955955505371094
#   }
#   relative_keypoints {
#     x: 0.3537288308143616
#     y: 0.3549655079841614
#   }
#   relative_keypoints {
#     x: 0.4305265247821808
#     y: 0.36726492643356323
#   }
#   relative_keypoints {
#     x: 0.3946862816810608
#     y: 0.45827871561050415
#   }
#   relative_keypoints {
#     x: 0.38851407170295715
#     y: 0.50821453332901
#   }
#   relative_keypoints {
#     x: 0.2964050769805908
#     y: 0.34379273653030396
#   }
#   relative_keypoints {
#     x: 0.4622361958026886
#     y: 0.3688868284225464
#   }
# }
#
# label_id: 0
# score: 0.9393266439437866
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.2813180685043335
#     ymin: 0.24451839923858643
#     width: 0.19015216827392578
#     height: 0.338046669960022
#   }
#   relative_keypoints {
#     x: 0.352750688791275
#     y: 0.3616774082183838
#   }
#   relative_keypoints {
#     x: 0.42907872796058655
#     y: 0.36466509103775024
#   }
#   relative_keypoints {
#     x: 0.39667871594429016
#     y: 0.4591742157936096
#   }
#   relative_keypoints {
#     x: 0.3896493911743164
#     y: 0.5054174065589905
#   }
# ...
#     y: 0.3750022053718567
#   }
#   relative_keypoints {
#     x: 0.43487030267715454
#     y: 0.2856677174568176
#   }
#   relative_keypoints {
#     x: 0.5868042707443237
#     y: 0.26298898458480835
#   }
# }
#
# label_id: 0
# score: 0.9220724105834961
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4223264157772064
#     ymin: 0.1454402208328247
#     width: 0.17785122990608215
#     height: 0.3161807060241699
#   }
#   relative_keypoints {
#     x: 0.4767000079154968
#     y: 0.2427322268486023
#   }
#   relative_keypoints {
#     x: 0.5495745539665222
#     y: 0.23414558172225952
#   }
#   relative_keypoints {
#     x: 0.5194548964500427
#     y: 0.31530576944351196
#   }
#   relative_keypoints {
#     x: 0.5218389630317688
#     y: 0.3749663233757019
#   }
#   relative_keypoints {
#     x: 0.43141424655914307
#     y: 0.27075451612472534
#   }
#   relative_keypoints {
#     x: 0.5892996191978455
#     y: 0.2482830286026001
#   }
# }
#
# label_id: 0
# score: 0.9348976016044617
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4249449074268341
#     ymin: 0.1562015414237976
#     width: 0.17226406931877136
#     height: 0.3062485456466675
#   }
#   relative_keypoints {
#     x: 0.4735107123851776
#     y: 0.25002074241638184
#   }
#   relative_keypoints {
#     x: 0.5460260510444641
#     y: 0.24356484413146973
#   }
#   relative_keypoints {
#     x: 0.5125569701194763
#     y: 0.3243970274925232
#   }
#   relative_keypoints {
#     x: 0.5154120326042175
#     y: 0.3806283473968506
#   }
#   relative_keypoints {
#     x: 0.4336588680744171
#     y: 0.27119994163513184
#   }
#   relative_keypoints {
#     x: 0.5886806845664978
#     y: 0.2542989253997803
#   }
# }
#
# label_id: 0
# score: 0.9173673391342163
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4245510399341583
#     ymin: 0.15935027599334717
#     width: 0.17067787051200867
#     height: 0.3034284710884094
#   }
#   relative_keypoints {
#     x: 0.4754120409488678
#     y: 0.2517056465148926
#   }
#   relative_keypoints {
#     x: 0.5484119057655334
#     y: 0.2424944043159485
#   }
#   relative_keypoints {
#     x: 0.5187138319015503
#     y: 0.32153141498565674
#   }
#   relative_keypoints {
#     x: 0.5210668444633484
#     y: 0.3796333074569702
#   }
#   relative_keypoints {
#     x: 0.43024393916130066
#     y: 0.2792125344276428
#   }
#   relative_keypoints {
#     x: 0.5866906046867371
#     y: 0.25455719232559204
#   }
# }
#
# label_id: 0
# score: 0.9243070483207703
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4219754934310913
#     ymin: 0.15620851516723633
#     width: 0.16637051105499268
#     height: 0.2957710027694702
#   }
#   relative_keypoints {
#     x: 0.4703878164291382
#     y: 0.25152820348739624
#   }
#   relative_keypoints {
#     x: 0.5425194501876831
#     y: 0.23371797800064087
#   }
#   relative_keypoints {
#     x: 0.5158662796020508
#     y: 0.3125198483467102
#   }
#   relative_keypoints {
#     x: 0.5199240446090698
#     y: 0.3684505224227905
#   }
#   relative_keypoints {
#     x: 0.4262608587741852
#     y: 0.28528761863708496
#   }
#   relative_keypoints {
#     x: 0.5800319314002991
#     y: 0.2443145513534546
#   }
# }
#
# label_id: 0
# score: 0.940302312374115
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4273833930492401
#     ymin: 0.16044384241104126
#     width: 0.16040924191474915
#     height: 0.28517258167266846
#   }
#   relative_keypoints {
#     x: 0.47741109132766724
#     y: 0.24243533611297607
#   }
#   relative_keypoints {
#     x: 0.5479848980903625
#     y: 0.2347361445426941
#   }
#   relative_keypoints {
#     x: 0.5214449167251587
#     y: 0.30193406343460083
#   }
#   relative_keypoints {
#     x: 0.5224834084510803
#     y: 0.3603513240814209
#   }
#   relative_keypoints {
#     x: 0.4295145869255066
#     y: 0.28029119968414307
#   }
#   relative_keypoints {
#     x: 0.5804874300956726
#     y: 0.25865447521209717
#   }
# }
#
# label_id: 0
# score: 0.8836319446563721
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42334067821502686
#     ymin: 0.14677119255065918
#     width: 0.16704392433166504
#     height: 0.29696744680404663
#   }
#   relative_keypoints {
#     x: 0.47251319885253906
#     y: 0.2326188087463379
#   }
#   relative_keypoints {
#     x: 0.5439004898071289
#     y: 0.22451436519622803
#   }
#   relative_keypoints {
#     x: 0.5143712759017944
#     y: 0.2875479459762573
#   }
#   relative_keypoints {
#     x: 0.5167456269264221
#     y: 0.3492274284362793
#   }
#   relative_keypoints {
#     x: 0.42952340841293335
#     y: 0.2752397060394287
#   }
#   relative_keypoints {
#     x: 0.5819119215011597
#     y: 0.2516597509384155
#   }
# }
#
# label_id: 0
# score: 0.9179356098175049
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.42172902822494507
#     ymin: 0.14018654823303223
#     width: 0.17059701681137085
#     height: 0.3032841086387634
#   }
#   relative_keypoints {
#     x: 0.4726768434047699
#     y: 0.21782386302947998
#   }
#   relative_keypoints {
#     x: 0.5490961074829102
#     y: 0.21854770183563232
#   }
#   relative_keypoints {
#     x: 0.5148749947547913
#     y: 0.27824050188064575
#   }
#   relative_keypoints {
#     x: 0.5140426158905029
#     y: 0.34568506479263306
#   }
#   relative_keypoints {
#     x: 0.4233205020427704
#     y: 0.26260215044021606
#   }
#   relative_keypoints {
#     x: 0.5857759714126587
#     y: 0.2601410150527954
#   }
# }
#
# label_id: 0
# score: 0.9324060082435608
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4151909053325653
#     ymin: 0.15178430080413818
#     width: 0.1626734435558319
#     height: 0.2891979217529297
#   }
#   relative_keypoints {
#     x: 0.4632711708545685
#     y: 0.2338072657585144
#   }
#   relative_keypoints {
#     x: 0.5359321236610413
#     y: 0.2300121784210205
#   }
#   relative_keypoints {
#     x: 0.5051022171974182
#     y: 0.2956559658050537
#   }
#   relative_keypoints {
#     x: 0.5060920119285583
#     y: 0.3541901111602783
#   }
#   relative_keypoints {
#     x: 0.41770610213279724
#     y: 0.2691648006439209
#   }
#   relative_keypoints {
#     x: 0.5711963176727295
#     y: 0.25607824325561523
#   }
# }
#
# label_id: 0
# score: 0.9503620266914368
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.4114997684955597
#     ymin: 0.15277975797653198
#     width: 0.16106995940208435
#     height: 0.28634709119796753
#   }
#   relative_keypoints {
#     x: 0.4580162763595581
#     y: 0.23269951343536377
#   }
#   relative_keypoints {
#     x: 0.530889630317688
#     y: 0.22650116682052612
#   }
#   relative_keypoints {
#     x: 0.500436544418335
#     y: 0.2909391522407532
#   }
#   relative_keypoints {
#     x: 0.502247154712677
#     y: 0.3504316210746765
#   }
#   relative_keypoints {
#     x: 0.41301682591438293
#     y: 0.27256476879119873
#   }
#   relative_keypoints {
#     x: 0.5676334500312805
#     y: 0.2537158727645874
#   }
# }
#
# label_id: 0
# score: 0.9378748536109924
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40550997853279114
#     ymin: 0.14270281791687012
#     width: 0.1621209681034088
#     height: 0.2882155179977417
#   }
#   relative_keypoints {
#     x: 0.4564339220523834
#     y: 0.22417670488357544
#   }
#   relative_keypoints {
#     x: 0.5278599262237549
#     y: 0.21969127655029297
#   }
#   relative_keypoints {
#     x: 0.4998902678489685
#     y: 0.2853296995162964
#   }
#   relative_keypoints {
#     x: 0.5002352595329285
#     y: 0.3436441421508789
#   }
#   relative_keypoints {
#     x: 0.40769216418266296
#     y: 0.2596452236175537
#   }
#   relative_keypoints {
#     x: 0.5603150725364685
#     y: 0.24356305599212646
#   }
# }
#
# label_id: 0
# score: 0.9406355023384094
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.40136775374412537
#     ymin: 0.14882153272628784
#     width: 0.16281816363334656
#     height: 0.28945475816726685
#   }
#   relative_keypoints {
#     x: 0.45502299070358276
#     y: 0.22239714860916138
#   }
#   relative_keypoints {
#     x: 0.5252606868743896
#     y: 0.2235848307609558
#   }
#   relative_keypoints {
#     x: 0.4972301721572876
#     y: 0.2821943759918213
#   }
#   relative_keypoints {
#     x: 0.4957612156867981
#     y: 0.34551072120666504
#   }
#   relative_keypoints {
#     x: 0.40478748083114624
#     y: 0.2624690532684326
#   }
#   relative_keypoints {
#     x: 0.5559872388839722
#     y: 0.25803273916244507
#   }
# }
#
# label_id: 0
# score: 0.9504253268241882
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.39767590165138245
#     ymin: 0.1563968062400818
#     width: 0.15868178009986877
#     height: 0.28210145235061646
#   }
#   relative_keypoints {
#     x: 0.4496697783470154
#     y: 0.2285863161087036
#   }
#   relative_keypoints {
#     x: 0.5198243260383606
#     y: 0.2302190661430359
#   }
#   relative_keypoints {
#     x: 0.49212008714675903
#     y: 0.2883368134498596
#   }
#   relative_keypoints {
#     x: 0.4903860092163086
#     y: 0.348339319229126
#   }
#   relative_keypoints {
#     x: 0.39910799264907837
#     y: 0.2661346197128296
#   }
#   relative_keypoints {
#     x: 0.5497568845748901
#     y: 0.26171332597732544
#   }
# }
#
# label_id: 0
# score: 0.9552463889122009
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3986106216907501
#     ymin: 0.163831889629364
#     width: 0.15297415852546692
#     height: 0.2719547152519226
#   }
#   relative_keypoints {
#     x: 0.44560763239860535
#     y: 0.23185038566589355
#   }
#   relative_keypoints {
#     x: 0.5133184790611267
#     y: 0.23610985279083252
#   }
#   relative_keypoints {
#     x: 0.4834462106227875
#     y: 0.2914799451828003
#   }
#   relative_keypoints {
#     x: 0.48132023215293884
#     y: 0.3495727777481079
#   }
#   relative_keypoints {
#     x: 0.39934688806533813
#     y: 0.2649487853050232
#   }
#   relative_keypoints {
#     x: 0.5455878973007202
#     y: 0.2689937353134155
#   }
# }
#
# label_id: 0
# score: 0.9430511593818665
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.38981449604034424
#     ymin: 0.16574931144714355
#     width: 0.15508204698562622
#     height: 0.2757015824317932
#   }
#   relative_keypoints {
#     x: 0.44344615936279297
#     y: 0.23114407062530518
#   }
#   relative_keypoints {
#     x: 0.5098870396614075
#     y: 0.2420642375946045
#   }
#   relative_keypoints {
#     x: 0.48226210474967957
#     y: 0.2948651909828186
#   }
#   relative_keypoints {
#     x: 0.4771784245967865
#     y: 0.3552340269088745
#   }
#   relative_keypoints {
#     x: 0.39170172810554504
#     y: 0.2626318335533142
#   }
#   relative_keypoints {
#     x: 0.5359106659889221
#     y: 0.27815085649490356
#   }
# }
# label_id: 0
# score: 0.9422206878662109
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3779495060443878
#     ymin: 0.16131532192230225
#     width: 0.16165223717689514
#     height: 0.28738123178482056
#   }
#   relative_keypoints {
#     x: 0.4388714134693146
#     y: 0.2272331714630127
#   }
#   relative_keypoints {
#     x: 0.5060741901397705
#     y: 0.2386946678161621
#   }
#   relative_keypoints {
#     x: 0.481597363948822
#     y: 0.2895146608352661
#   }
#   relative_keypoints {
#     x: 0.47494691610336304
#     y: 0.35567641258239746
#   }
#   relative_keypoints {
#     x: 0.3801613450050354
#     y: 0.264690637588501
#   }
#   relative_keypoints {
#     x: 0.5275248289108276
#     y: 0.28029775619506836
#   }
# }
#
# label_id: 0
# score: 0.9394873976707458
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.36197522282600403
#     ymin: 0.1573033332824707
#     width: 0.17609378695487976
#     height: 0.31305599212646484
#   }
#   relative_keypoints {
#     x: 0.43203774094581604
#     y: 0.23749208450317383
#   }
#   relative_keypoints {
#     x: 0.5027400255203247
#     y: 0.23940163850784302
#   }
#   relative_keypoints {
#     x: 0.48127689957618713
#     y: 0.30583488941192627
#   }
#   relative_keypoints {
#     x: 0.47567445039749146
#     y: 0.3743441700935364
#   }
#   relative_keypoints {
#     x: 0.3673258125782013
#     y: 0.2758514881134033
#   }
#   relative_keypoints {
#     x: 0.523021936416626
#     y: 0.2730906009674072
#   }
# }
#
# label_id: 0
# score: 0.9616034030914307
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3653757572174072
#     ymin: 0.16197699308395386
#     width: 0.17162388563156128
#     height: 0.3051096796989441
#   }
#   relative_keypoints {
#     x: 0.4311881363391876
#     y: 0.2418568730354309
#   }
#   relative_keypoints {
#     x: 0.5000408291816711
#     y: 0.24766147136688232
#   }
#   relative_keypoints {
#     x: 0.47542011737823486
#     y: 0.3159021735191345
#   }
#   relative_keypoints {
#     x: 0.46994999051094055
#     y: 0.37780290842056274
#   }
#   relative_keypoints {
#     x: 0.37228676676750183
#     y: 0.26735925674438477
#   }
#   relative_keypoints {
#     x: 0.5234646797180176
#     y: 0.2741212844848633
#   }
# }
#
# label_id: 0
# score: 0.9431000351905823
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.35682809352874756
#     ymin: 0.1660442352294922
#     width: 0.1739155650138855
#     height: 0.3091839551925659
#   }
#   relative_keypoints {
#     x: 0.41991424560546875
#     y: 0.25098657608032227
#   }
#   relative_keypoints {
#     x: 0.4918299913406372
#     y: 0.2502286434173584
#   }
#   relative_keypoints {
#     x: 0.46663886308670044
#     y: 0.32270580530166626
#   }
#   relative_keypoints {
#     x: 0.46404334902763367
#     y: 0.3852694034576416
#   }
#   relative_keypoints {
#     x: 0.36362937092781067
#     y: 0.2818721532821655
#   }
#   relative_keypoints {
#     x: 0.5185580253601074
#     y: 0.2738075256347656
#   }
# }
#
# label_id: 0
# score: 0.9431629180908203
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.359070748090744
#     ymin: 0.18165647983551025
#     width: 0.16596010327339172
#     height: 0.29504096508026123
#   }
#   relative_keypoints {
#     x: 0.4187054932117462
#     y: 0.2598622441291809
#   }
#   relative_keypoints {
#     x: 0.4889335632324219
#     y: 0.2721747159957886
#   }
#   relative_keypoints {
#     x: 0.4594065248966217
#     y: 0.3389056324958801
#   }
#   relative_keypoints {
#     x: 0.4537873864173889
#     y: 0.39468127489089966
#   }
#   relative_keypoints {
#     x: 0.363648921251297
#     y: 0.27448827028274536
#   }
#   relative_keypoints {
#     x: 0.5147744417190552
#     y: 0.29450398683547974
#   }
# }
#
# label_id: 0
# score: 0.9199338555335999
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3513561189174652
#     ymin: 0.18203449249267578
#     width: 0.1703316867351532
#     height: 0.3028123378753662
#   }
#   relative_keypoints {
#     x: 0.4193243086338043
#     y: 0.26828962564468384
#   }
#   relative_keypoints {
#     x: 0.4864547550678253
#     y: 0.27385491132736206
#   }
#   relative_keypoints {
#     x: 0.46413204073905945
#     y: 0.34599387645721436
#   }
#   relative_keypoints {
#     x: 0.458333820104599
#     y: 0.40188658237457275
#   }
#   relative_keypoints {
#     x: 0.35912394523620605
#     y: 0.2841797471046448
#   }
#   relative_keypoints {
#     x: 0.506390392780304
#     y: 0.2900012135505676
#   }
# }
#
# label_id: 0
# score: 0.9407625794410706
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.3524840474128723
#     ymin: 0.18431025743484497
#     width: 0.16365855932235718
#     height: 0.29094910621643066
#   }
#   relative_keypoints {
#     x: 0.4074219763278961
#     y: 0.2720862030982971
#   }
#   relative_keypoints {
#     x: 0.4779207408428192
#     y: 0.2740481495857239
#   }
#   relative_keypoints {
#     x: 0.449474960565567
#     y: 0.34921908378601074
#   }
#   relative_keypoints {
#     x: 0.4478585720062256
#     y: 0.3985283374786377
#   }
#   relative_keypoints {
#     x: 0.3576127290725708
#     y: 0.2853237986564636
#   }
#   relative_keypoints {
#     x: 0.5074949264526367
#     y: 0.2833283543586731
#   }
# }
#
# label_id: 0
# score: 0.9295616745948792
# location_data {
#   format: RELATIVE_BOUNDING_BOX
#   relative_bounding_box {
#     xmin: 0.34869056940078735
#     ymin: 0.17325228452682495
#     width: 0.16645574569702148
#     height: 0.2959216833114624
#   }
#   relative_keypoints {
#     x: 0.4058319330215454
#     y: 0.26757240295410156
#   }
#   relative_keypoints {
#     x: 0.47844913601875305
#     y: 0.2561783790588379
#   }
#   relative_keypoints {
#     x: 0.45609819889068604
#     y: 0.332730233669281
#   }
#   relative_keypoints {
#     x: 0.4564264416694641
#     y: 0.38733357191085815
#   }
#   relative_keypoints {
#     x: 0.35058659315109253
#     y: 0.2988708019256592
#   }
#   relative_keypoints {
#     x: 0.5050713419914246
#     y: 0.26744186878204346
#   }
# }
